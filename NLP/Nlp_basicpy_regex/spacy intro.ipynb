# %% [markdown]
# #  spacy intro
#
# - large volume of text analyser (centiment , torkanize : classify)
# - libry lode
# - pipeline objective
# - token
# - part of speach
# - token attribute usage
#
#
#
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# documentation and useful datas Ref:
#
# https://spacy.io/usage

# %%
import spacy

# %%
english_nlp = spacy.load("en_core_web_sm")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9120\1732402594.py in <module>
# ----> 1 english_nlp = spacy.load("en_core_web_sm")
#
# ~\anaconda3\lib\site-packages\spacy\__init__.py in load(name, vocab, disable, exclude, config)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name, vocab=vocab, disable=disable, exclude=exclude, config=config
#      53     )
#
# ~\anaconda3\lib\site-packages\spacy\util.py in load_model(name, vocab, disable, exclude, config)
#     425     if name in OLD_MODEL_SHORTCUTS:
#     426         raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 427     raise IOError(Errors.E050.format(name=name))
#     428
#     429
#
# ...

# %%
print(spacy.util.get_data_path())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9120\2728979791.py in <module>
# ----> 1 print(spacy.util.get_data_path())
#       2
#
# AttributeError: module 'spacy.util' has no attribute 'get_data_path'
